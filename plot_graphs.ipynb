# %%
# read /Users/jameschua/ml/tconrl/eval_results/large_results_replace/high_reward_completions.csv into pandas
import pandas as pd
from typing import List

high_reward_completions = pd.read_csv('/Users/jameschua/ml/tconrl/eval_results/large_results/high_reward_completions.csv')

rewards: List[float] = high_reward_completions["actual_reward"].tolist()

# %%
from conditionme.statistics.plot_dist_plot import plot_distribution

high_reward_plot = plot_distribution(
    scores=rewards,
    title="Max target reward performance",
    ylabel="Count",
    xlabel="Actual reward"
)
high_reward_plot.figure

# %%
low_reward_completions = pd.read_csv('/Users/jameschua/ml/tconrl/eval_results/large_results/low_reward_completions.csv')

low_rewards: List[float] = low_reward_completions["actual_reward"].tolist()

# %%
low_reward_plot = plot_distribution(
    scores=low_rewards,
    title="Min target reward performance",
    ylabel="Count",
    xlabel="Actual reward",
)

# %%
low_reward_plot.figure
